# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('tempi.csv')

# %%
X=list(data.columns)[2:]
data_job1=data[data['job']==1]
data_job2=data[data['job']==2]
data_job1
# Out:
#        System  job     0.1     0.3      0.5      0.7        1      1.3
# 0  SPARK_CORE    1   9.583  11.824   16.012   18.426   21.965   25.213  \
# 2        HIVE    1  40.496  55.580  115.187  119.261  135.070  152.103
# 4  MAP-REDUCE    1   5.650   5.798    6.739    7.889    8.955    9.738
# 6   SPARK-SQL    1  28.374  41.220   45.507   53.927   70.502   86.997
#
#        1.5      1.7        2
# 0   27.975   29.687   33.084
# 2  159.950  212.162  220.862
# 4   11.674   11.753   12.765
# 6  112.927  119.662  126.289

# %%
def plot_data(data,path,title):
    fig, ax = plt.subplots(figsize=(8, 6))

    for _, row in data.iterrows():
        system = row['System']
        values = row[2:]
        ax.plot(X, values, label=system)

    # Set labels and title
    ax.set_xlabel('Dataset-dimension')
    ax.set_ylabel('Execution-time (sec)')
    ax.set_title(title)
    ax.legend()

    plt.savefig(path)
    # Display the plot
    plt.show()

# %%
#LOCAL EXECUTION

plot_data(data_job1,'Local_job1.jpeg',"job1-LOCAL")
plot_data(data_job2,'Local_job2.jpeg',"job2-LOCAL")

# %%
#CLUSTER EXECUTION
data_cluster=pd.read_csv('tempi_cluster.csv')
X=list(data_cluster.columns)[2:]
data_cluster_job1=data_cluster[data_cluster['job']==1]
data_cluster_job2=data_cluster[data_cluster['job']==2]
data_cluster_job1
# Out:
#        System  job     0.1     0.3     0.5     0.7       1     1.3     1.5
# 0        HIVE    1  45.236  52.714  55.578  60.062  61.814  70.000  71.350  \
# 2  SPARK_CORE    1  12.200  16.134  20.550  24.235  29.900  34.270  43.460
# 4   SPARK_SQL    1  31.239  47.410  54.282  58.182  62.871  71.269  78.339
#
#       1.7        2
# 0  84.400  152.850
# 2  41.000   45.870
# 4  85.171   97.232

# %%
plot_data(data_cluster_job1,'Cluster_job1.jpeg',"job1-CLUSTER")
plot_data(data_cluster_job2,'Cluster_job2.jpeg',"job2-CLUSTER")
